# %%
library(tidyverse)
library(lubridate)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.0     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   0.8.5
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     intersect, setdiff, union
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
cetaceans <- read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2018/2018-12-18/allCetaceanData.csv")  %>% 
                    janitor::clean_names() %>% 
                    select(-x1) %>% 
                    mutate(birth_year = as.integer(birth_year), 
                           age = ifelse(status == "Died", 
                                        year(status_date) - birth_year, NA), 
                           species = str_replace(species, "Beluga Whale", "Beluga"))
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   X1 = col_double(),
#   originDate = col_date(format = ""),
#   statusDate = col_date(format = ""),
#   transferDate = col_date(format = ""),
#   entryDate = col_date(format = "")
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# “NAs introduced by coercion”

# %%
# two types of NA
cetaceans %>% 
    count(age) %>% 
    filter(is.na(age))
# Out:
#   age n
# 1 NA  604
# 2 NA  636

# %%
names(cetaceans)
#head(cetaceans)
# Out:
#  [1] "species"         "id"              "name"            "sex"
#  [5] "accuracy"        "birth_year"      "acquisition"     "origin_date"
#  [9] "origin_location" "mother"          "father"          "transfers"
# [13] "currently"       "region"          "status"          "status_date"
# [17] "cod"             "notes"           "transfer_date"   "transfer"
# [21] "entry_date"      "age"

# %%
cetaceans %>% 
    count(acquisition, sort = TRUE)
# Out:
#   acquisition n
# 1 Capture     1214
# 2 Born         776
# 3 Unknown       95
# 4 Rescue        89
# 5 Stillbirth    15
# 6 Miscarriage    5

# %%
cetaceans %>% 
    filter(status == "Died", 
           !is.na(birth_year), !is.na(status_date)) %>% 
    ggplot(aes(age)) + 
        geom_histogram() +
        geom_vline(aes(xintercept = median(age)), 
                   color = "pink", size = 2, alpha = 0.3)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
cetaceans %>% 
    count(species = fct_lump(species, 10)) %>% 
    mutate(species = fct_reorder(species, n)) %>% 
    ggplot(aes(n, species)) + 
        geom_col()
# Out:
# plot without title

# %%
cetaceans %>% 
    filter(!is.na(birth_year), !is.na(status_date)) %>% 
    select(age, species, birth_year, status_date) %>% 
    mutate(species = fct_lump(species, 5),
           m_age = mean(age),
           species = fct_reorder(species, m_age)) %>% 
    ggplot(aes(age, species)) + 
        geom_boxplot()
# Out:
# Warning message:
# “Removed 46 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
cetaceans %>%
    count(acquisition, origin_location, sort = TRUE) %>% 
    filter(origin_location != "Unknown")
# Out:
#     acquisition origin_location             n
# 1   Capture     Gulf of Mexico, MS, US      116
# 2   Capture     Pacific Ocean, CA, US        85
# 3   Born        SeaWorld San Diego           81
# 4   Born        SeaWorld Orlando             78
# 5   Born        SeaWorld San Antonio         72
# 6   Born        U.S. Navy                    63
# 7   Capture     Florida Keys                 56
# 8   Born        Dolphin Research Center      45
# 9   Born        Discovery Cove               37
# 10  Capture     Florida                      36
# 11  Capture     Hudson Bay, Canada           36
# 12  Born        Marineland Florida           30
# 13  Capture     Unknown, US                  27
# 14  Born        Dolphins Plus Oceanside      26
# 15  Capture     Gulf of Mexico, FL, US       26
# 16  Born        Dolphin Quest Hawaii         25
# 17  Capture     Atlantic Ocean, FL           21
# 18  Born        Brookfield Zoo               18
# 19  Born        Six Flags Discovery Kingdom  18
# 20  Capture     Unknown, FL, US              15
# 21  Born        Theater of the Sea           14
# 22  Capture     Gulf of Mexico, FL?          14
# 23  Born        Indianapolis Zoo             12
# 24  Born        Mirage Dolphin Habitat       12
# 25  Capture     Pacific Ocean, Japan         12
# 26  Capture     Straits of Magellan, Chile   12
# 27  Born        Miami Seaquarium              9
# 28  Born        Shedd Aquarium                9
# 29  Capture     Atlantic Ocean, FL, US        9
# 30  Capture     Texas, Gulf of Mexico         9
# ⋮   ⋮           ⋮                           ⋮
# 105 Rescue      Indian River Lagoon, FL     1
# 106 Rescue      Indian Rocks Beach, FL      1
# 107 Rescue      Jacksonville, FL            1
# 108 Rescue      Key West, FL                1
# 109 Rescue      Lower Matecumbe Key         1
# 110 Rescue      Matagorda Island, TX        1
# 111 Rescue      Melbourne Beach, FL         1
# 112 Rescue      Moriya coast, Japan         1
# 113 Rescue      Mosquito Lagoon, FL         1
# 114 Rescue      Mustang Island, TX, US      1
# 115 Rescue      Pacific Ocean, CA, US       1
# 116 Rescue      Panama City, FL             1
# 117 Rescue      Ponce Inlet, FL             1
# 118 Rescue      Port Isabel, TX, US         1
# 119 Rescue      Quintana Beach, TX          1
# 120 Rescue      Redington Beach, FL         1
# 121 Rescue      Sanibel Island, FL          1
# 122 Rescue      Sanibel Island, FL, US      1
# 123 Rescue      Shell Island, FL, US        1
# 124 Rescue      South Padre Is., TX         1
# 125 Rescue      Tampa Bay, FL               1
# 126 Rescue      Texas, Gulf Coast           1
# 127 Rescue      Texas, Gulf of Mexico       1
# 128 Rescue      Three Sisters Is., FL, US   1
# 129 Rescue      Unknown, FL                 1
# 130 Rescue      Vero Beach, FL              1
# 131 Stillbirth  Dolphin Connection          1
# 132 Stillbirth  Dolphins Plus Oceanside     1
# 133 Stillbirth  Mirage Dolphin Habitat      1
# 134 Stillbirth  SeaWorld San Antonio        1

# %%
cetaceans %>% 
    ggplot(aes(origin_date, fill = acquisition)) + 
        geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# “Removed 69 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# ## Spinograms

# %%
cetaceans %>% 
    filter(year(origin_date) >= 1970) %>% 
    count(decade = 5 *(year(origin_date) %/% 5), 
          acquisition) %>% 
    complete(acquisition, decade, fill = list(n = 0)) %>% 
    group_by(decade) %>% 
    mutate(percent = n / sum(n), 
           acquisition = fct_reorder(acquisition, percent)) %>% 
    ggplot(aes(decade, percent, fill = acquisition)) +
        geom_area() +
        scale_y_continuous(labels = scales::percent_format()) +
        labs(y = "% of cetaceans recorded", x = "year")
# Out:
# plot without title

# %% [markdown]
# ## Fuzzy joins to group categories

# %%
library(fuzzyjoin)

regexes <- tribble(
    ~regex, ~category,
    "Unknown", "Unknown", 
    "Florida|FL", "Florida",
    "Texas|TX", "Texas",
    "SeaWorld", "SeaWorld", 
    "Pacific", "Pacific Ocean",
    "Atlantic", "Atlantic Ocean"
)

regexes
# Out:
#   regex      category
# 1 Unknown    Unknown
# 2 Florida|FL Florida
# 3 Texas|TX   Texas
# 4 SeaWorld   SeaWorld
# 5 Pacific    Pacific Ocean
# 6 Atlantic   Atlantic Ocean

# %%
cetaceans_annotated <- cetaceans %>% 
    mutate(unique_id = row_number()) %>% 
    regex_left_join(regexes, c(origin_location = "regex")) %>% 
    distinct(unique_id, .keep_all = TRUE) %>% 
    mutate(category = coalesce(category, origin_location))

# %%
cetaceans_annotated %>%  
    filter(acquisition == "Born", 
           year(origin_date) >= 1970) %>%
    mutate(category = fct_lump(category, 6)) %>% 
    count(decade = 5 *(year(origin_date) %/% 5), 
          category) %>% 
    complete(category, decade, fill = list(n = 0)) %>% 
    group_by(decade) %>% 
    mutate(percent = n / sum(n), 
           category = fct_reorder(category, percent)) %>% 
    ggplot(aes(decade, percent, fill = category)) +
        geom_area() +
        scale_y_continuous(labels = scales::percent_format()) +
        labs(title = "Cetaceus born in captivity",
             y = "% of cetaceans recorded", 
             x = "year")
# Out:
# plot without title

# %%
cetaceans_annotated %>%  
    filter(acquisition == "Capture") %>%
    mutate(category = fct_lump(category, 5), 
           category = fct_reorder(category, category, length)) %>% 
    ggplot(aes(origin_date, fill = category)) +
        geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# “Removed 2 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# ## Survival Analysis

# %%
library(survival)

# %%
cetaceans_survival <- cetaceans %>% 
    filter(status %in% c("Alive", "Died")) %>% 
    mutate(death_year = ifelse(status == "Alive", 2017, year(status_date)), 
           status = ifelse(status == "Alive", 0, 1), 
           age = death_year - birth_year) %>% 
    filter(!is.na(death_year)) %>% 
    select(age, death_year, birth_year, status, sex, acquisition, species) %>% 
    filter(death_year >= birth_year)

head(cetaceans_survival)
# Out:
#   age death_year birth_year status sex acquisition species
# 1 28  2017       1989       0      F   Born        Bottlenose
# 2 44  2017       1973       0      F   Born        Bottlenose
# 3 39  2017       1978       0      M   Born        Bottlenose
# 4 38  2017       1979       0      F   Born        Bottlenose
# 5 38  2017       1979       0      M   Born        Bottlenose
# 6 37  2017       1980       0      F   Born        Bottlenose

# %%
mod0 <- survfit(Surv(age, status) ~ 1, cetaceans_survival)

# %%
#plot(mod0)
tidy(mod0) %>% head()
# Out:
#   time n.risk n.event n.censor estimate  std.error   conf.high conf.low
# 1 0    1416   120      1       0.9152542 0.008086424 0.9298758 0.9008626
# 2 1    1295    23     13       0.8989988 0.008908030 0.9148326 0.8834390
# 3 2    1259    29     11       0.8782911 0.009903532 0.8955057 0.8614073
# 4 3    1219    31     17       0.8559555 0.010930977 0.8744917 0.8378123
# 5 4    1171    36     16       0.8296409 0.012106715 0.8495627 0.8101863
# 6 5    1119    38     16       0.8014673 0.013341173 0.8227006 0.7807819

# %%
library(broom)
tidy(mod0) %>% 
    ggplot(aes(time, estimate)) +
        geom_line() +
        geom_ribbon(aes(ymin = conf.low, ymax = conf.high), alpha = 0.2)
# Out:
# plot without title

# %%
mod1 <- survfit(Surv(age, status) ~ sex, cetaceans_survival)

# %%
tidy(mod1) %>% 
    filter(strata != "sex=U") %>% 
    ggplot(aes(time, estimate, color = strata)) +
        geom_line() +
        geom_ribbon(aes(ymin = conf.low, ymax = conf.high), alpha = 0.2) +
        scale_y_continuous(labels = scales::percent_format())
# Out:
# plot without title

# %%
mod2 <- coxph(Surv(age, status) ~ sex, cetaceans_survival)
# Out:
# Call:
# coxph(formula = Surv(age, status) ~ sex, data = cetaceans_survival)
#
#         coef exp(coef) se(coef)     z      p
# sexM 0.09840   1.10341  0.06594 1.492 0.1356
# sexU 0.85148   2.34312  0.22895 3.719 0.0002
#
# Likelihood ratio test=12.15  on 2 df, p=0.0023
# n= 1416, number of events= 952

# %%
mod2 %>% 
    tidy()
# Out:
#   term estimate   std.error  statistic p.value      conf.low    conf.high
# 1 sexM 0.09840386 0.06594024 1.492319  0.1356155560 -0.03083662 0.2276443
# 2 sexU 0.85148438 0.22895485 3.719006  0.0002000086  0.40274112 1.3002276

# %%
mod3 <- survfit(Surv(age, status) ~ acquisition, cetaceans_survival)

# %%
tidy(mod3) %>% 
    filter(strata != "acquisition=Unknown") %>% 
    ggplot(aes(time, estimate, color = strata)) +
        geom_line() +
        geom_ribbon(aes(ymin = conf.low, ymax = conf.high), alpha = 0.2) +
        scale_y_continuous(labels = scales::percent_format()) +
        labs(y = "Estimated % survival")
# Out:
# plot without title
