# %%
#devtools::install_github("thebioengineer/tidytuesdayR")
library(tidyverse)
library(tidytuesdayR)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.0     v purrr   0.3.4
# v tibble  3.0.0     v dplyr   0.8.5
# v tidyr   1.0.2     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.5.0
#
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
library(lubridate)
library(janitor)
# Out:
# Attaching package: 'lubridate'
#
#
# The following objects are masked from 'package:dplyr':
#
#     intersect, setdiff, union
#
#
# The following objects are masked from 'package:base':
#
#     date, intersect, setdiff, union
#
#
#
# Attaching package: 'janitor'
#
#
# The following objects are masked from 'package:stats':
#
#     chisq.test, fisher.test

# %%
tuesdata <- tidytuesdayR::tt_load(2020, week = 15)
# Out:
# --- Downloading #TidyTuesday Information for 2020-04-07 ----
#
# --- Identified 3 files available for download ----
#
# --- Downloading files ---
#
# Warning message:
# "230562 parsing failures.
#   row        col           expected actual                                                                         file
# 22069 bib_number 1/0/T/F/TRUE/FALSE     41 'C:\Users\fedeZzZ\AppData\Local\Temp\RtmpMVe11M\file2d8049a5418f.csv'
# 22070 bib_number 1/0/T/F/TRUE/FALSE     11 'C:\Users\fedeZzZ\AppData\Local\Temp\RtmpMVe11M\file2d8049a5418f.csv'
# 22071 bib_number 1/0/T/F/TRUE/FALSE     2  'C:\Users\fedeZzZ\AppData\Local\Temp\RtmpMVe11M\file2d8049a5418f.csv'
# 22072 bib_number 1/0/T/F/TRUE/FALSE     3  'C:\Users\fedeZzZ\AppData\Local\Temp\RtmpMVe11M\file2d8049a5418f.csv'
# 22073 bib_number 1/0/T/F/TRUE/FALSE     5  'C:\Users\fedeZzZ\AppData\Local\Temp\RtmpMVe11M\file2d8049a5418f.csv'
# ..... .......... .................. ...... ............................................................................
# See problems(...) for more details.
# "
# --- Download complete ---

# %%
tdf_winners <- tuesdata$tdf_winners %>% 
                            mutate(year = year(start_date), 
                                   speed = distance / time_overall)
tdf_stages <- tuesdata$tdf_stages %>%  
                        clean_names()  %>% 
                        mutate(year = year(date))
stage_data <- tuesdata$stage_data %>%  clean_names()

# %%
tdf_winners %>% head()
# Out:
#   edition start_date winner_name         winner_team    distance time_overall
# 1 1       1903-07-01 Maurice Garin       La Française   2428     94.55389
# 2 2       1904-07-02 Henri Cornet        Conte          2428     96.09861
# 3 3       1905-07-09 Louis Trousselier   Peugeot–Wolber 2994           NA
# 4 4       1906-07-04 René Pottier        Peugeot–Wolber 4637           NA
# 5 5       1907-07-08 Lucien Petit-Breton Peugeot–Wolber 4488           NA
# 6 6       1908-07-13 Lucien Petit-Breton Peugeot–Wolber 4497           NA
#   time_margin stage_wins stages_led height ... age born       died
# 1 2.989167    3           6         1.62   ... 32  1871-03-03 1957-02-19
# 2 2.270556    1           3           NA   ... 19  1884-08-04 1941-03-18
# 3       NA    5          10           NA   ... 24  1881-06-29 1939-04-24
# 4       NA    5          12           NA   ... 27  1879-06-05 1907-01-25
# 5       NA    2           5           NA   ... 24  1882-10-18 1917-12-20
# 6       NA    5          13           NA   ... 25  1882-10-18 1917-12-20
#   full_name            nickname                 birth_town      birth_country
# 1 NA                   The Little Chimney-sweep Arvier          Italy
# 2 NA                   Le rigolo (The joker)    Desvres         France
# 3 NA                   Levaloy / Trou-trou      Paris           France
# 4 NA                   NA                       Moret-sur-Loing France
# 5 Lucien Georges Mazan Lucien Petit-Breton      Plessé          France
# 6 Lucien Georges Mazan Lucien Petit-Breton      Plessé          France
#   nationality year speed
# 1  France     1903 25.67848
# 2  France     1904 25.26571
# 3  France     1905       NA
# 4  France     1906       NA
# 5  France     1907       NA
# 6  France     1908       NA

# %%
skimr::skim(tdf_winners)
# Out:
# -- Data Summary ------------------------
#                            Values
# Name                       tdf_winners
# Number of rows             106
# Number of columns          21
# _______________________
# Column type frequency:
#   character                7
#   Date                     3
#   numeric                  11
# ________________________
# Group variables            None
#
# -- Variable type: character ----------------------------------------------------
# # A tibble: 7 x 8
#   skim_variable n_missing complete_rate   min   max empty n_unique whitespace
# * <chr>             <int>         <dbl> <int> <int> <int>    <int>      <int>
# 1 winner_name           0         1        10    19     0       63          0
# 2 winner_team           0         1         3    33     0       48          0
# 3 full_name            60         0.434    15    33     0       23          0
# 4 nickname             32         0.698     1    96     0       37          0
# 5 birth_town            0         1         3    28     0       58          0
# 6 birth_country         0         1         3    11     0       15          0
# 7 nationality           0         1         6    14     0       14        106
#
# -- Variable type: Date ---------------------------------------------------------
# # A tibble: 3 x 7
#   skim_variable n_missing complete_rate min        max        median
# * <chr>             <int>         <dbl> <date>     <date>     <date>
# 1 start_date            0         1     1903-07-01 2019-07-06 1966-12-24
# 2 born                  0         1     1871-03-03 1997-01-13 1940-12-27
# 3 died                 50         0.528 1907-01-25 2019-08-16 1980-04-10
#   n_unique
# *    <int>
# 1      106
# 2       63
# 3       38
#
# -- Variable type: numeric ------------------------------------------------------
# # A tibble: 11 x 11
#    skim_variable n_missing complete_rate     mean       sd         p0       p25
#  * <chr>             <int>         <dbl>    <dbl>    <dbl>      <dbl>     <dbl>
#  1 edition               0         1       53.5    30.7       1         27.2
#  2 distance              0         1     4212.    704.     2428       3658.
#  3 time_overall          8         0.925  126.     41.6      82.1       92.6
#  4 time_margin           8         0.925    0.268   0.476     0.00222    0.0508
#  5 stage_wins            0         1        2.74    1.84      0          1
#  6 stages_led            0         1       10.8     5.31      1          6.25
#  7 height               40         0.623    1.78    0.0570    1.61       1.74
#  8 weight               39         0.632   69.3     6.59     52         64.5
#  9 age                   0         1       27.7     3.35     19         26
# 10 year                  0         1     1964.     34.1    1903       1933.
# 11 speed                 8         0.925   34.8     5.09     24.0       31.8
#         p50      p75    p100 hist
#  *    <dbl>    <dbl>   <dbl> <chr>
#  1   53.5     79.8    106    <U+2587><U+2587><U+2587><U+2587><U+2587>
#  2 4156.    4652.    5745    <U+2581><U+2587><U+2587><U+2586><U+2583>
#  3  115.     143.     239.   <U+2587><U+2585><U+2582><U+2581><U+2582>
#  4    0.102    0.250    2.99 <U+2587><U+2581><U+2581><U+2581><U+2581>
#  5    2        4        8    <U+2586><U+2587><U+2583><U+2582><U+2581>
#  6   12       14       22    <U+2586><U+2587><U+2587><U+2587><U+2583>
#  7    1.77     1.82     1.9  <U+2581><U+2581><U+2587><U+2583><U+2582>
#  8   69       74       88    <U+2581><U+2586><U+2587><U+2587><U+2581>
#  9   28       30       36    <U+2581><U+2583><U+2587><U+2583><U+2582>
# 10 1966.    1993.    2019    <U+2587><U+2585><U+2587><U+2587><U+2587>
# 11   35.9     39.2     41.7  <U+2583><U+2582><U+2585><U+2587><U+2587>

# %%
tdf_winners %>% 
            count(winner_name, sort = TRUE) %>%
            mutate(winner_name  = fct_reorder(winner_name, n))  %>% 
            ggplot(aes(n, winner_name)) + 
                geom_col() +
                scale_x_continuous(breaks = 1:7) +
                labs(y = "", title = "21 winners in 63 editions")
# Out:
# plot without title

# %%
tdf_winners %>% 
            count(birth_country, sort = TRUE) %>%
            mutate(birth_country = fct_reorder(birth_country, n))  %>% 
            ggplot(aes(n, birth_country)) + 
                geom_col() +
                labs(y = "", title = "Countries with the most winners")
# Out:
# plot without title

# %%
tdf_winners  %>% 
        count(winner_name, birth_country, sort = TRUE) %>% 
        head()
# Out:
#   winner_name      birth_country n
# 1 Lance Armstrong  USA           7
# 2 Bernard Hinault  France        5
# 3 Eddy Merckx      Belgium       5
# 4 Jacques Anquetil France        5
# 5 Miguel Induráin  Spain         5
# 6 Chris Froome     Kenya         4

# %%
by_decade <- tdf_winners %>%
                    group_by(decade = 10 * (year %/% 10)) %>%
                    filter(decade >= 1910) %>%
                    summarise(winner_age = mean(age, na.rm = TRUE), 
                              winner_height = mean(height, na.rm = TRUE), 
                              winner_weight = mean(weight, na.rm = TRUE), 
                              winner_margin = mean(time_margin, na.rm = TRUE), 
                              winner_speed = mean(speed, na.rm = TRUE))

# %%
by_decade %>% 
        ggplot(aes(decade, 60 * winner_margin)) +
            geom_line() +
            labs(y = "winning margin in minutes", 
                 x = "decade", title = "Races are getting closer")
# Out:
# plot without title

# %%
by_decade %>% 
        ggplot(aes(decade, winner_speed)) +
            geom_line() +
                expand_limits(y = 0) + 
                labs(y = "Winner's average speed (km/h)", 
                     x = "Decade", 
                     title = "Winners are getting faster")
# Out:
# plot without title

# %%
names(tdf_winners)
# Out:
#  [1] "edition"       "start_date"    "winner_name"   "winner_team"
#  [5] "distance"      "time_overall"  "time_margin"   "stage_wins"
#  [9] "stages_led"    "height"        "weight"        "age"
# [13] "born"          "died"          "full_name"     "nickname"
# [17] "birth_town"    "birth_country" "nationality"   "year"
# [21] "speed"

# %% [markdown]
# ### Life expentacy

# %%
library(survival)

# %%
surv_model <- tdf_winners %>% 
                    distinct(winner_name, .keep_all = TRUE) %>%
                    transmute(winner_name, 
                              birth_year = year(born), 
                              death_year = year(died), 
                              dead = as.integer(!is.na(death_year))) %>%
                    mutate(age_at_death = coalesce(death_year, 2020) - birth_year)  %>% 
                    survfit(Surv(age_at_death, dead) ~ 1, data = .)

# %%
surv_model %>% plot()
# Out:
# plot without title

# %%
library(broom)
glance(surv_model)

#median life expectancy of a tdf winner is 77
# Out:
#   records n.max n.start events rmean    rmean.std.error median conf.low
# 1 63      63    63      38     69.62491 2.685674        77     71
#   conf.high
# 1 82

# %%
tdf_winners %>% 
        distinct(winner_name, .keep_all = TRUE) %>%
        filter(!is.na(died)) %>% 
        dim()

# 38 out of 63 have died...
# Out:
# [1] 38 21

# %% [markdown]
# # Stage Data:

# %%
stage_data  %>% dim()
stage_data  %>% head()
# Out:
# [1] 255752     11
#   edition year stage_results_id rank time rider            age team points
# 1 1       1903 stage-1          1    13S  Garin Maurice    32  NA   100
# 2 1       1903 stage-1          2    55S  Pagie Émile      32  NA    70
# 3 1       1903 stage-1          3    59S  Georget Léon     23  NA    50
# 4 1       1903 stage-1          4    48S  Augereau Fernand 20  NA    40
# 5 1       1903 stage-1          5    53S  Fischer Jean     36  NA    32
# 6 1       1903 stage-1          6    53S  Kerff Marcel     37  NA    26
#   elapsed bib_number
# 1 13S     NA
# 2 8S      NA
# 3 12S     NA
# 4 1S      NA
# 5 6S      NA
# 6 6S      NA

# %%
tdf_stages  %>% dim()
tdf_stages  %>% head()
# Out:
# [1] 2236    9
#   stage date       distance origin            destination
# 1 1     2017-07-01  14.0    Düsseldorf        Düsseldorf
# 2 2     2017-07-02 203.5    Düsseldorf        Liège
# 3 3     2017-07-03 212.5    Verviers          Longwy
# 4 4     2017-07-04 207.5    Mondorf-les-Bains Vittel
# 5 5     2017-07-05 160.5    Vittel            La Planche des Belles Filles
# 6 6     2017-07-06 216.0    Vesoul            Troyes
#   type                  winner         winner_country year
# 1 Individual time trial Geraint Thomas GBR            2017
# 2 Flat stage            Marcel Kittel  GER            2017
# 3 Medium mountain stage Peter Sagan    SVK            2017
# 4 Flat stage            Arnaud Démare  FRA            2017
# 5 Medium mountain stage Fabio Aru      ITA            2017
# 6 Flat stage            Marcel Kittel  GER            2017

# %%
tdf_stages %>%  
            group_by(year)  %>% 
            summarise(distance = sum(distance)) %>% 
            ggplot(aes(year, distance)) + 
                    geom_line() +
                    expand_limits(y = 0) +
                    labs(x = "year",
                         y = "distance", 
                         title = "Tdf is getting shorter", 
                         subtitle = "1903 was the first and shortest edition")
# Out:
# plot without title

# %%
stage_data_ranks <- 
        stage_data  %>% 
        group_by(year, rider)  %>%
        summarise(total_points = sum(points, na.rm = TRUE))  %>% 
        mutate(points_rank = percent_rank(total_points))  %>% 
        ungroup()

# %%
head(stage_data_ranks)
# Out:
#   year rider                 total_points points_rank
# 1 1903 Aucouturier Hippolyte 200          0.9772727
# 2 1903 Augereau Fernand      180          0.9545455
# 3 1903 Barroy Lucien           0          0.0000000
# 4 1903 Barthelmann Ludwig      0          0.0000000
# 5 1903 Beaugendre François    60          0.7045455
# 6 1903 Borot Georges           0          0.0000000

# %%
stage_data_percentile <- 
        stage_data %>% 
        separate(stage_results_id, into = c("name", "stage"))  %>%        
        inner_join(stage_data_ranks, by = c("year", "rider"))  %>%
        group_by(year, stage)  %>% 
        mutate(rank = as.integer(rank), 
               finishers = sum(!is.na(rank)))  %>% 
        ungroup()  %>% 
        mutate(percentile_rank = 1 - rank / finishers)
# Out:
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# ...
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"
# Warning message:
# "NAs introduced by coercion"

# %%
stage_data_percentile  %>%  
        select(year, rider, percentile_rank)  %>% 
        head()
# Out:
#   year rider            percentile_rank
# 1 1903 Garin Maurice    0.9729730
# 2 1903 Pagie Émile      0.9459459
# 3 1903 Georget Léon     0.9189189
# 4 1903 Augereau Fernand 0.8918919
# 5 1903 Fischer Jean     0.8648649
# 6 1903 Kerff Marcel     0.8378378

# %%
stage_data_percentile  %>% 
        filter(stage == 1)  %>% 
        select(year, rider, 
               percentile_first_stage = percentile_rank, 
               total_points, 
               points_rank)   %>%
        mutate(first_stage_bin = cut(percentile_first_stage, seq(0, 1, 0.1)))  %>% 
        filter(!is.na(first_stage_bin))  %>% 
        ggplot(aes(first_stage_bin, points_rank)) +
            geom_boxplot() +
            scale_y_continuous(labels = scales::percent) +
            labs(x = "Decile performance in the first stage", 
                 y = "Overall points percentile")
# Out:
# plot without title

# %% [markdown]
# ### 2017 tdf animation

# %%
library(gganimate)
# Out:
# No renderer backend detected. gganimate will default to writing frames to separate files
# Consider installing:
# - the `gifski` package for gif output
# - the `av` package for video output
# and restarting the R session

# %%
top_10_2017 <- 
        stage_data_ranks  %>%  
        filter(year == 2017)  %>% 
        top_n(10, total_points)

top_10_2017
# Out:
#    year rider                total_points points_rank
# 1  2017 Bardet Romain        284          0.9644670
# 2  2017 Barguil Warren       340          0.9746193
# 3  2017 Boasson Hagen Edvald 422          0.9898477
# 4  2017 Démare Arnaud        274          0.9593909
# 5  2017 Froome Chris         346          0.9847716
# 6  2017 Greipel André        262          0.9543147
# 7  2017 Groenewegen Dylan    304          0.9695431
# 8  2017 Kittel Marcel        518          1.0000000
# 9  2017 Matthews Michael     430          0.9949239
# 10 2017 Urán Rigoberto       342          0.9796954

# %%
stage_data_percentile  %>%
        filter(year == 2017)  %>% 
        semi_join(top_10_2017, by = "rider")  %>% 
        mutate(stage = as.integer(stage), 
               points = coalesce(points, 0))  %>% 
        group_by(rider)  %>% 
        mutate(cumulative_poins = cumsum(points)) %>%
        ungroup() %>%
        mutate(rider = fct_reorder(rider, total_points)) %>% 
        ggplot(aes(cumulative_poins, rider, fill = cumulative_poins)) +
            geom_col() +
            #to animate: transition_time(stage)
            facet_wrap(~stage)
# Out:
# plot without title
